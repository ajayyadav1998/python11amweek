# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from decimal import Decimal

# %%
import matplotlib
col = list(matplotlib.colors.cnames.values())

# %%
col
# Out:
# ['#F0F8FF',
#  '#FAEBD7',
#  '#00FFFF',
#  '#7FFFD4',
#  '#F0FFFF',
#  '#F5F5DC',
#  '#FFE4C4',
#  '#000000',
#  '#FFEBCD',
#  '#0000FF',
#  '#8A2BE2',
#  '#A52A2A',
#  '#DEB887',
#  '#5F9EA0',
#  '#7FFF00',
#  '#D2691E',
#  '#FF7F50',
#  '#6495ED',
#  '#FFF8DC',
#  '#DC143C',
#  '#00FFFF',
#  '#00008B',
#  '#008B8B',
#  '#B8860B',
#  '#A9A9A9',
#  '#006400',
#  '#A9A9A9',
#  '#BDB76B',
#  '#8B008B',
#  '#556B2F',
#  '#FF8C00',
#  '#9932CC',
#  '#8B0000',
#  '#E9967A',
#  '#8FBC8F',
#  '#483D8B',
#  '#2F4F4F',
#  '#2F4F4F',
#  '#00CED1',
#  '#9400D3',
#  '#FF1493',
#  '#00BFFF',
#  '#696969',
#  '#696969',
#  '#1E90FF',
#  '#B22222',
#  '#FFFAF0',
#  '#228B22',
#  '#FF00FF',
#  '#DCDCDC',
#  '#F8F8FF',
#  '#FFD700',
#  '#DAA520',
#  '#808080',
#  '#008000',
#  '#ADFF2F',
#  '#808080',
#  '#F0FFF0',
#  '#FF69B4',
#  '#CD5C5C',
#  '#4B0082',
#  '#FFFFF0',
#  '#F0E68C',
#  '#E6E6FA',
#  '#FFF0F5',
#  '#7CFC00',
#  '#FFFACD',
#  '#ADD8E6',
#  '#F08080',
#  '#E0FFFF',
#  '#FAFAD2',
# ...

# %%
df = pd.read_csv('E:/datasets/h1b.csv')# csv -- comma seperated file

# %%
df.head()
# Out:
#    Unnamed: 0          CASE_STATUS  \
# 0           1  CERTIFIED-WITHDRAWN
# 1           2  CERTIFIED-WITHDRAWN
# 2           3  CERTIFIED-WITHDRAWN
# 3           4  CERTIFIED-WITHDRAWN
# 4           5            WITHDRAWN
#
#                                        EMPLOYER_NAME  \
# 0                             UNIVERSITY OF MICHIGAN
# 1                             GOODMAN NETWORKS, INC.
# 2                          PORTS AMERICA GROUP, INC.
# 3  GATES CORPORATION, A WHOLLY-OWNED SUBSIDIARY O...
# 4                          PEABODY INVESTMENTS CORP.
#
#                         SOC_NAME                     JOB_TITLE  \
# 0  BIOCHEMISTS AND BIOPHYSICISTS  POSTDOCTORAL RESEARCH FELLOW
# 1               CHIEF EXECUTIVES       CHIEF OPERATING OFFICER
# 2               CHIEF EXECUTIVES         CHIEF PROCESS OFFICER
# 3               CHIEF EXECUTIVES   REGIONAL PRESIDEN, AMERICAS
# 4               CHIEF EXECUTIVES  PRESIDENT MONGOLIA AND INDIA
#
# ...

# %%
df.dropna(inplace=True)   # dropping na values here

# %%
df.shape  # checking the number of rows and columns
# Out:
# (2877765, 11)

# %%
df.info() # checking info of dataframe
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 2877765 entries, 0 to 3002444
# Data columns (total 11 columns):
# Unnamed: 0            int64
# CASE_STATUS           object
# EMPLOYER_NAME         object
# SOC_NAME              object
# JOB_TITLE             object
# FULL_TIME_POSITION    object
# PREVAILING_WAGE       float64
# YEAR                  float64
# WORKSITE              object
# lon                   float64
# lat                   float64
# dtypes: float64(4), int64(1), object(6)
# memory usage: 263.5+ MB

# %%
df.columns = [var.lower() for var in df.columns] # changing the column name in small

# %%
df.head()
# Out:
#    unnamed: 0          case_status  \
# 0           1  CERTIFIED-WITHDRAWN
# 1           2  CERTIFIED-WITHDRAWN
# 2           3  CERTIFIED-WITHDRAWN
# 3           4  CERTIFIED-WITHDRAWN
# 4           5            WITHDRAWN
#
#                                        employer_name  \
# 0                             UNIVERSITY OF MICHIGAN
# 1                             GOODMAN NETWORKS, INC.
# 2                          PORTS AMERICA GROUP, INC.
# 3  GATES CORPORATION, A WHOLLY-OWNED SUBSIDIARY O...
# 4                          PEABODY INVESTMENTS CORP.
#
#                         soc_name                     job_title  \
# 0  BIOCHEMISTS AND BIOPHYSICISTS  POSTDOCTORAL RESEARCH FELLOW
# 1               CHIEF EXECUTIVES       CHIEF OPERATING OFFICER
# 2               CHIEF EXECUTIVES         CHIEF PROCESS OFFICER
# 3               CHIEF EXECUTIVES   REGIONAL PRESIDEN, AMERICAS
# 4               CHIEF EXECUTIVES  PRESIDENT MONGOLIA AND INDIA
#
# ...

# %%
df.columns
# Out:
# Index(['unnamed: 0', 'case_status', 'employer_name', 'soc_name', 'job_title',
#        'full_time_position', 'prevailing_wage', 'year', 'worksite', 'lon',
#        'lat'],
#       dtype='object')

# %%
df.drop(['unnamed: 0','lon','lat'],inplace=True,axis=1)

# %%
df.columns = ['case_status', 'companies', 'soc_name', 'job_title',
       'full_t_pos', 'wage', 'year', 'worksite']

# %%
df.head()
# Out:
#            case_status                                          companies  \
# 0  CERTIFIED-WITHDRAWN                             UNIVERSITY OF MICHIGAN
# 1  CERTIFIED-WITHDRAWN                             GOODMAN NETWORKS, INC.
# 2  CERTIFIED-WITHDRAWN                          PORTS AMERICA GROUP, INC.
# 3  CERTIFIED-WITHDRAWN  GATES CORPORATION, A WHOLLY-OWNED SUBSIDIARY O...
# 4            WITHDRAWN                          PEABODY INVESTMENTS CORP.
#
#                         soc_name                     job_title full_t_pos  \
# 0  BIOCHEMISTS AND BIOPHYSICISTS  POSTDOCTORAL RESEARCH FELLOW          N
# 1               CHIEF EXECUTIVES       CHIEF OPERATING OFFICER          Y
# 2               CHIEF EXECUTIVES         CHIEF PROCESS OFFICER          Y
# 3               CHIEF EXECUTIVES   REGIONAL PRESIDEN, AMERICAS          Y
# 4               CHIEF EXECUTIVES  PRESIDENT MONGOLIA AND INDIA          Y
#
#        wage    year                 worksite
# ...

# %% [markdown]
# # Top 15 companies to hire

# %%
plt.figure(figsize=(10,5))
df.companies.value_counts()[:15].plot(kind='bar',title='top 15 companies to hire',color=col[::-2])
plt.show()

# %%
df.case_status.unique()
# Out:
# array(['CERTIFIED-WITHDRAWN', 'WITHDRAWN', 'CERTIFIED', 'DENIED',
#        'REJECTED', 'INVALIDATED',
#        'PENDING QUALITY AND COMPLIANCE REVIEW - UNASSIGNED'], dtype=object)

# %%
cs = df.case_status.value_counts()[:4]

# %%
cs.index
# Out:
# Index(['CERTIFIED', 'CERTIFIED-WITHDRAWN', 'DENIED', 'WITHDRAWN'], dtype='object')

# %%
cs.values
# Out:
# array([2512114,  195721,   85161,   84752], dtype=int64)

# %% [markdown]
# # Pie plot of Case Status Column

# %%
plt.figure(figsize=(12,6))
plt.pie(x=cs.values,labels=cs.index,autopct='%.f%%',explode=[0.2,0,0,0],shadow=True)
plt.title('Pie of Case status')
plt.show()

# %%
df.head()
# Out:
#            case_status                                          companies  \
# 0  CERTIFIED-WITHDRAWN                             UNIVERSITY OF MICHIGAN
# 1  CERTIFIED-WITHDRAWN                             GOODMAN NETWORKS, INC.
# 2  CERTIFIED-WITHDRAWN                          PORTS AMERICA GROUP, INC.
# 3  CERTIFIED-WITHDRAWN  GATES CORPORATION, A WHOLLY-OWNED SUBSIDIARY O...
# 4            WITHDRAWN                          PEABODY INVESTMENTS CORP.
#
#                         soc_name                     job_title full_t_pos  \
# 0  BIOCHEMISTS AND BIOPHYSICISTS  POSTDOCTORAL RESEARCH FELLOW          N
# 1               CHIEF EXECUTIVES       CHIEF OPERATING OFFICER          Y
# 2               CHIEF EXECUTIVES         CHIEF PROCESS OFFICER          Y
# 3               CHIEF EXECUTIVES   REGIONAL PRESIDEN, AMERICAS          Y
# 4               CHIEF EXECUTIVES  PRESIDENT MONGOLIA AND INDIA          Y
#
#        wage    year                 worksite
# ...

# %%
mwage = df.nlargest(10,'wage')[['companies','wage']].set_index('companies')

# %%
mwage
# Out:
#                                              wage
# companies
# GUARDIAN HEALTHCARE PROVIDERS, INC.  6.997607e+09
# SCIVANTAGE, INC.                     1.007814e+09
# DISCOVER PRODUCTS INC.               8.201323e+08
# IDEXCEL, INC.                        7.099999e+08
# ARKRIT LLC                           6.169317e+08
# HOWARD HUGHES MEDICAL INSTITUTE      4.134726e+08
# GOOGLE INC.                          4.103154e+08
# ICAP CORPORATES LLC                  4.066379e+08
# BAYSHORE GLOBAL MANAGEMENT LLC       3.783437e+08
# HUNTSWORTH HEALTH NORTH AMERICA LLC  3.610381e+08

# %%
type(mwage)
# Out:
# pandas.core.frame.DataFrame

# %%
mwage.index
# Out:
# Index(['GUARDIAN HEALTHCARE PROVIDERS, INC.', 'SCIVANTAGE, INC.',
#        'DISCOVER PRODUCTS INC.', 'IDEXCEL, INC.', 'ARKRIT LLC',
#        'HOWARD HUGHES MEDICAL INSTITUTE', 'GOOGLE INC.', 'ICAP CORPORATES LLC',
#        'BAYSHORE GLOBAL MANAGEMENT LLC',
#        'HUNTSWORTH HEALTH NORTH AMERICA LLC'],
#       dtype='object', name='companies')

# %%
mwage.values.flatten()
# Out:
# array([6.99760672e+09, 1.00781408e+09, 8.20132347e+08, 7.09999949e+08,
#        6.16931693e+08, 4.13472579e+08, 4.10315360e+08, 4.06637920e+08,
#        3.78343680e+08, 3.61038080e+08])

# %%
plt.figure(figsize=(13,8),facecolor='seagreen')
plt.rcParams['text.color'] = 'gold'
plt.bar(x=mwage.index,height=mwage.values.flatten())
plt.xticks(rotation=90)
plt.title('max wages paid by companies')
plt.ylabel('max Wages')
plt.xlabel('companies')
plt.show()

# %%
df.head()
# Out:
#            case_status                                          companies  \
# 0  CERTIFIED-WITHDRAWN                             UNIVERSITY OF MICHIGAN
# 1  CERTIFIED-WITHDRAWN                             GOODMAN NETWORKS, INC.
# 2  CERTIFIED-WITHDRAWN                          PORTS AMERICA GROUP, INC.
# 3  CERTIFIED-WITHDRAWN  GATES CORPORATION, A WHOLLY-OWNED SUBSIDIARY O...
# 4            WITHDRAWN                          PEABODY INVESTMENTS CORP.
#
#                         soc_name                     job_title full_t_pos  \
# 0  BIOCHEMISTS AND BIOPHYSICISTS  POSTDOCTORAL RESEARCH FELLOW          N
# 1               CHIEF EXECUTIVES       CHIEF OPERATING OFFICER          Y
# 2               CHIEF EXECUTIVES         CHIEF PROCESS OFFICER          Y
# 3               CHIEF EXECUTIVES   REGIONAL PRESIDEN, AMERICAS          Y
# 4               CHIEF EXECUTIVES  PRESIDENT MONGOLIA AND INDIA          Y
#
#        wage    year                 worksite
# ...

# %%
year = df.groupby('year')['case_status'].count()

# %% [markdown]
# # Files applied in year

# %%
plt.figure(figsize=(10,5),facecolor='mediumorchid')
plt.rcParams['text.color'] = 'black'
color=['fuchsia','deeppink','mediumvioletred','m','plum','violet']
plt.bar(x=year.index,height=year.values,color=color)
plt.title('Files applied in a particular year')
plt.xlabel('Year')
plt.ylabel('Number of values')
plt.show()

# %%
df.year.value_counts()
# Out:
# 2016.0    629299
# 2015.0    600120
# 2014.0    498027
# 2013.0    422427
# 2012.0    394267
# 2011.0    333625
# Name: year, dtype: int64

# %%
df['worksite'] = df.worksite.apply(lambda val : val.split(',')[1])

# %%
df.head()
# Out:
#            case_status                                          companies  \
# 0  CERTIFIED-WITHDRAWN                             UNIVERSITY OF MICHIGAN
# 1  CERTIFIED-WITHDRAWN                             GOODMAN NETWORKS, INC.
# 2  CERTIFIED-WITHDRAWN                          PORTS AMERICA GROUP, INC.
# 3  CERTIFIED-WITHDRAWN  GATES CORPORATION, A WHOLLY-OWNED SUBSIDIARY O...
# 4            WITHDRAWN                          PEABODY INVESTMENTS CORP.
#
#                         soc_name                     job_title full_t_pos  \
# 0  BIOCHEMISTS AND BIOPHYSICISTS  POSTDOCTORAL RESEARCH FELLOW          N
# 1               CHIEF EXECUTIVES       CHIEF OPERATING OFFICER          Y
# 2               CHIEF EXECUTIVES         CHIEF PROCESS OFFICER          Y
# 3               CHIEF EXECUTIVES   REGIONAL PRESIDEN, AMERICAS          Y
# 4               CHIEF EXECUTIVES  PRESIDENT MONGOLIA AND INDIA          Y
#
#        wage    year     worksite
# 0   36067.0  2016.0     MICHIGAN
# ...

# %%
topwork = df.worksite.value_counts()[:10]

# %%
topwork
# Out:
#  CALIFORNIA       548539
#  TEXAS            286704
#  NEW YORK         282429
#  NEW JERSEY       206876
#  ILLINOIS         154843
#  MASSACHUSETTS    112659
#  PENNSYLVANIA     103729
#  WASHINGTON       100754
#  FLORIDA          100384
#  GEORGIA           99679
# Name: worksite, dtype: int64

# %%
df.case_status.unique()
# Out:
# array(['CERTIFIED-WITHDRAWN', 'WITHDRAWN', 'CERTIFIED', 'DENIED',
#        'REJECTED', 'INVALIDATED',
#        'PENDING QUALITY AND COMPLIANCE REVIEW - UNASSIGNED'], dtype=object)

# %%
topdenied = df[df.case_status == 'DENIED']['worksite'].value_counts()[:10]

# %%
topdenied
# Out:
#  CALIFORNIA       16901
#  NEW YORK         11858
#  TEXAS             8070
#  FLORIDA           5064
#  NEW JERSEY        4488
#  ILLINOIS          3612
#  MASSACHUSETTS     3369
#  VIRGINIA          2622
#  GEORGIA           2533
#  PENNSYLVANIA      2390
# Name: worksite, dtype: int64

# %% [markdown]
# # Top most workstite and denied worksite

# %%
fig = plt.figure(figsize=(15,10),facecolor='cornflowerblue')
color =['slateblue','darkviolet','violet','indigo','magenta','purple','darkorchid','darkviolet'] 


ax1 = fig.add_axes([0,0,0.45,0.45]) #left,bottom,width,height
ax2 = fig.add_axes([0.5,0,0.45,0.45])

ax1.bar(x=topwork.index,height=topwork[:],color=color)
ax1.set_title('top 10 worksites')
ax1.set_xticklabels(labels=topwork.index,rotation=90)
ax1.set_xlabel('WorkSite Names')
ax1.set_ylabel('Number of values')

ax2.bar(x=topdenied.index,height=topdenied[:],color=col[::-2])
ax2.set_title('top 10 denied worksites')
ax2.set_xticklabels(labels=topdenied.index,rotation=90)
ax2.set_xlabel('Worksite Names')
ax2.set_ylabel('Number of values')

plt.show()

# %%
df.head()
# Out:
#            case_status                                          companies  \
# 0  CERTIFIED-WITHDRAWN                             UNIVERSITY OF MICHIGAN
# 1  CERTIFIED-WITHDRAWN                             GOODMAN NETWORKS, INC.
# 2  CERTIFIED-WITHDRAWN                          PORTS AMERICA GROUP, INC.
# 3  CERTIFIED-WITHDRAWN  GATES CORPORATION, A WHOLLY-OWNED SUBSIDIARY O...
# 4            WITHDRAWN                          PEABODY INVESTMENTS CORP.
#
#                         soc_name                     job_title full_t_pos  \
# 0  BIOCHEMISTS AND BIOPHYSICISTS  POSTDOCTORAL RESEARCH FELLOW          N
# 1               CHIEF EXECUTIVES       CHIEF OPERATING OFFICER          Y
# 2               CHIEF EXECUTIVES         CHIEF PROCESS OFFICER          Y
# 3               CHIEF EXECUTIVES   REGIONAL PRESIDEN, AMERICAS          Y
# 4               CHIEF EXECUTIVES  PRESIDENT MONGOLIA AND INDIA          Y
#
#        wage    year     worksite
# 0   36067.0  2016.0     MICHIGAN
# ...

# %%
df.job_title.tolist()
# Out:
# ['POSTDOCTORAL RESEARCH FELLOW',
#  'CHIEF OPERATING OFFICER',
#  'CHIEF PROCESS OFFICER',
#  'REGIONAL PRESIDEN, AMERICAS',
#  'PRESIDENT MONGOLIA AND INDIA',
#  'EXECUTIVE V P, GLOBAL DEVELOPMENT AND PRESIDENT, LATIN AMERI',
#  'CHIEF OPERATING OFFICER',
#  'CHIEF OPERATIONS OFFICER',
#  'PRESIDENT',
#  'CHIEF INFORMATION OFFICER, HEINZ NORTH AMERICA',
#  'VICE PRESIDENT AND CHIEF HUMAN RESOURCES OFFICER',
#  'CHIEF COMMERCIAL OFFICER',
#  'BOARD MEMBER',
#  'CHIEF FINANCIAL OFFICER',
#  'VICE PRESIDENT OF FINANCE',
#  'GENERAL MANAGER, OPERATIONS',
#  'CEO',
#  'PRESIDENT, NORTHEAST REGION',
#  'CHIEF OPERATING OFFICER (COO)',
#  'GENERAL MANAGER, OPERATIONS',
#  'CEO',
#  'CHIEF FINANCIAL OFFICER',
#  'CHIEF OPERATING OFFICER',
#  'CEO',
#  'CHIEF EXECUTIVE OFFICER',
#  'CHIEF BUSINESS OFFICER',
#  'VICE PRESIDENT OF ENGINEERING',
#  'EXECUTIVE DIRECTOR',
#  'VICE PRESIDENT, BUSINESS DEVELOPMENT',
#  'HEAD OF US SALES',
#  'CHIEF FINANCIAL OFFICER',
#  'CHIEF OPERATING OFFICER',
# ...

# %%
df.job_title.isin(['BUSINESS ANALYST']).sum()
# Out:
# 38781

# %%
job = ['DATA SCIENTIST','DATA ANALYST','BUSINESS ANALYST','DATA ENGINEER']
total = []

for var in job:
    d = df[df.job_title == var]['job_title'].count()
    total.append(d)
    
    
plt.figure(figsize=(10,5),facecolor='crimson')
plt.bar(x=job,height=total[:],color=['m','r','g','y'])
plt.title('Data scientist overall posts')
plt.xlabel('Names of different postitions')
plt.ylabel('Number of values of total jobs')
plt.show()

# %%
c = np.array([1,2,3,4,5,6,7,8])

# %%
d = c.copy()

# %%
plt.figure(figsize=(10,5),facecolor='crimson')

plt.plot(c,d,'red',alpha=1.0)
plt.plot(c,d*1,'red',linestyle=':',alpha=1)
plt.plot(c,d*2,'red',linestyle='-.',alpha=1)
plt.plot(c,d*3,'red',linestyle='-.',alpha=1)
plt.plot(c,d*4,'yellow',alpha=1)
plt.plot(c,d*5,'yellow',linestyle=':',alpha=1)
plt.plot(c,d*6,'yellow',linestyle='-.',alpha=1)
plt.plot(c,d*7,'yellow',linestyle='-.',alpha=1)
plt.plot(c,d*8,'green',alpha=1)
plt.plot(c,d*9,'green',linestyle=':',alpha=1)
plt.plot(c,d*10,'green',linestyle='-.',alpha=1)
plt.plot(c,d*11,'green',linestyle='-.',alpha=1)
plt.plot(c,d*12,'skyblue',alpha=1)
plt.plot(c,d*13,'skyblue',linestyle=':',alpha=1)
plt.plot(c,d*14,'skyblue',linestyle='-.',alpha=1)
plt.plot(c,d*15,'skyblue',linestyle='-.',alpha=1)
plt.plot(c,d*16,'blue',alpha=1)
plt.plot(c,d*17,'blue',linestyle=':',alpha=1)
plt.plot(c,d*18,'blue',linestyle='-.',alpha=1)
plt.plot(c,d*19,'blue',linestyle='-.',alpha=1)

plt.title('Just Time Pass')

plt.savefig('C:/Users/Ajay/Desktop/myimage.jpg',facecolor='crimson',dpi=200)
plt.show()

# %%
plt.figure(figsize=(10,5),facecolor='hotpink')
for var in range(1000):
    plt.plot(c,d,'red',alpha=1.0)
    plt.plot(c,d*var,'red',linestyle=':',alpha=1)
    plt.plot(c,d*var,'red',linestyle='-.',alpha=1)
    plt.plot(c,d*var,'red',linestyle='-.',alpha=1)
